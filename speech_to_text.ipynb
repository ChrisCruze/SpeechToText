# %% [markdown]
# #https://github.com/Uberi/speech_recognition/blob/master/examples/background_listening.py
# https://github.com/Uberi/speech_recognition/blob/master/examples/microphone_recognition.py
# https://www.thepythoncode.com/article/using-speech-recognition-to-convert-speech-to-text-python

# %%
# importing libraries 
import speech_recognition as sr 
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence

# create a speech recognition object
r = sr.Recognizer()

# a function that splits the audio file into chunks
# and applies speech recognition
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 500,
        # adjust this per requirement
        silence_thresh = sound.dBFS-14,
        # keep the silence for 1 second, adjustable as well
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text
path = "11-1-21 (Mon) 317PM .wav"
print("\nFull text:", get_large_audio_transcription(path))
# Out:
# audio-chunks/chunk1.wav : If you look at an end user journey and i'll just give you an example cuz if we flushed it out with use that this many of our pigs at work.
# audio-chunks/chunk2.wav : If you look at these are journey of deploying of visualizations into production that he's our journey is not started when i click the button to deploy.
# audio-chunks/chunk3.wav : Production started when i say.
# audio-chunks/chunk4.wav : My mind i've developed the dashboard.
# audio-chunks/chunk5.wav : I want it in production.
# audio-chunks/chunk6.wav : Now i know i need to go and you know that's technically when when the journey starts cuz i don't know what i'm doing i have to go search for the answer of how to find it we can't really control much about that but that doesn't necessarily mean it's not part of the journey i click on the button.
# audio-chunks/chunk7.wav : Out of my house.
# audio-chunks/chunk8.wav : And that is what i'm looking to have as a starting point for all.
# Error:
# audio-chunks/chunk10.wav : Journeys to get access to tools.
# audio-chunks/chunk11.wav : Journey to share work clothes to put your clothes production to run work was eccentric point is when the user can no longer take the next step on their own.
# audio-chunks/chunk12.wav : They require an automation something else somebody else to step in interview interfere so.
# audio-chunks/chunk13.wav : Whitsett.
# audio-chunks/chunk14.wav : I was tableau i want to be able to have a metric.
# audio-chunks/chunk15.wav : Did i say it takes.
# audio-chunks/chunk16.wav : Two days we got a tableau dashboard into its production.
# audio-chunks/chunk17.wav : Analysts on the front end would look at them say that my experience it takes that's accurate.
# audio-chunks/chunk18.wav : Well one at 1 and 1/2 of those days is actually waiting for your manager to approve it not on a saturday.
# audio-chunks/chunk19.wav : That is the system say got the approval.
# audio-chunks/chunk20.wav : Pushed it into production that's the message that we want to be able to deliver to the analysts and we're doing it on a weekly basis so.
# audio-chunks/chunk21.wav : Looking at those metrics week-over-week i do a lot of them will change a lot.
# Error:
# audio-chunks/chunk23.wav : We just want to get that user experience.
# Error:
# audio-chunks/chunk25.wav : Triangle.
# audio-chunks/chunk26.wav : Are we as a team will come up with or need to come up with certain journeys.
# audio-chunks/chunk27.wav : Against the start clicking the stopwatch is the last step that they can do on their own before they have to make it somebody else's problem and then.
# audio-chunks/chunk28.wav : And pointed whatever that intent was his result.
# audio-chunks/chunk29.wav : Gotcha.
# audio-chunks/chunk30.wav : That makes sense.
# audio-chunks/chunk31.wav : That's really good contacts.
# Error:
# audio-chunks/chunk33.wav : You know this stuff here.
# audio-chunks/chunk34.wav : They have to.
# audio-chunks/chunk35.wav : Dad.
# audio-chunks/chunk36.wav : Geneseo honor all that good stuff.
# audio-chunks/chunk37.wav : And i think i seen that stopwatch makes sense that i think it starts here but i'll look more into it and then i'll.
# Error:
# audio-chunks/chunk39.wav : Provide that information as well.
# audio-chunks/chunk40.wav : And there could be a back-and-forth again to someone grab td2 would be.
# Error:
# audio-chunks/chunk42.wav : Go for psych mpd2 it says envoy the click that so form out.
# audio-chunks/chunk43.wav : Go.
# audio-chunks/chunk44.wav : And then it could be a back-and-forth between.
# audio-chunks/chunk45.wav : I have to do and things i have to do.
# Error:
# Error:
# audio-chunks/chunk48.wav : I make sense.
# audio-chunks/chunk49.wav : Yeah luckily there is as great onboarding. so i think it'll be a good.
# audio-chunks/chunk50.wav : Starting point.
# audio-chunks/chunk51.wav : And i should have you.
# audio-chunks/chunk52.wav : What i told chris is that.
# audio-chunks/chunk53.wav : We would start the stopwatch at the last step that a person.
# audio-chunks/chunk54.wav : What i am.
# audio-chunks/chunk55.wav : Recognizing that i don't capture when i do that is if the forms that the user has to fill out to click the button to sasa fit go and start stopwatch.
# audio-chunks/chunk56.wav : Is egregious and horrible and paving.
# audio-chunks/chunk57.wav : Slingo if you have a way with mpd2 to say no no we've got a very clear way the.
# audio-chunks/chunk58.wav : The user starts on the floor man gauges with it and then they click this events you could start stopwatch earlier when they open the forum.
# Error:
# audio-chunks/chunk60.wav : Ideally would be able to track that at least without fixing the tableau you can't because they.
# audio-chunks/chunk61.wav : Open it up.
# audio-chunks/chunk62.wav : Goes off and do something else and then come back and it's not really something that you'd be able to easily track.
# Error:
# audio-chunks/chunk64.wav : What makes sense.
# audio-chunks/chunk65.wav : And then only other.
# audio-chunks/chunk66.wav : Question i think on that aspect is.
# audio-chunks/chunk67.wav : Is there any might differ based on which route.
# audio-chunks/chunk68.wav : The person might take.
# audio-chunks/chunk69.wav : So.
# Error:
# audio-chunks/chunk71.wav : Especially this.
# Error:
# audio-chunks/chunk73.wav : Two different ways to connect to empty to and this is where i guess this would be after the onboarding process but you think this.
# audio-chunks/chunk74.wav : Should be included within that journey or.
# audio-chunks/chunk75.wav : Can you connect auntie to you know in these five different ways and it might vary depending.
# audio-chunks/chunk76.wav : What is so i'm sorry what was the question i guess it's part of.
# audio-chunks/chunk77.wav : The envoy would you consider this as part of on voiding.
# audio-chunks/chunk78.wav : Like getting the shoes for getting the outfit stool.
# audio-chunks/chunk79.wav : Getting all these tools.
# Error:
# audio-chunks/chunk81.wav : Would you think that that's okay.
# Error:
# audio-chunks/chunk83.wav : Would be what i would do is i would say.
# audio-chunks/chunk84.wav : Yes we want these are the first start using it and let's see if the data bears out that the moment they get that email that says.
# audio-chunks/chunk85.wav : Congratulation and whatever it is.
# audio-chunks/chunk86.wav : If we could just measure that time and will determine whether to include it in your not.
# Error:
# Error:
# Error:
# audio-chunks/chunk90.wav : Take that time worker but that also looks of the time that they.
# audio-chunks/chunk91.wav : Are able to do it to where they first executed.
# audio-chunks/chunk92.wav : Cool that make sense.
# Error:
# audio-chunks/chunk94.wav : Yeah and luckily i'm meeting tomorrow with one of the tenants.
# audio-chunks/chunk95.wav : So it'll be in a good i'm just trying to get to know the tenants that way i can like run it something by them it to see if it sounds right so after i get the numbers off.
# audio-chunks/chunk96.wav : Justin running.
# audio-chunks/chunk97.wav : Let's just make sure.
# Error:
# Error:
# audio-chunks/chunk100.wav : Some other items here just so you know questionnaire.
# audio-chunks/chunk101.wav : Everyday i'm during i'm part of the.
# audio-chunks/chunk102.wav : Part of the stand up.
# audio-chunks/chunk103.wav : But all three.
# audio-chunks/chunk104.wav : And i wonder things are.
# audio-chunks/chunk105.wav : You know it's korn band name.
# audio-chunks/chunk106.wav : And wondering it like there's obviously a lot of ways to improve their processes specially.
# audio-chunks/chunk107.wav : Navien a kanban team.
# audio-chunks/chunk108.wav : I guess my question is.
# Error:
# audio-chunks/chunk110.wav : Should i should i should i should i help improve.
# audio-chunks/chunk111.wav : The process of the camdenton cuz i know we don't have a scrum master that's more the scrum masters role.
# audio-chunks/chunk112.wav : And i know leslie she was really just there listening and when they're fires relation.
# audio-chunks/chunk113.wav : I guess i'm kind of answer my own question.
# audio-chunks/chunk114.wav : Okay.
# Error:
# audio-chunks/chunk116.wav : I don't have an answer for you whatever you think it will take to do the job better if it's the answer is a that there should be a scrum master where you guys.
# Error:
# Error:
# audio-chunks/chunk119.wav : Yeah.
# audio-chunks/chunk120.wav : Anton 11 datapoint i was thinking to capture at least from from that whole year process is.
# audio-chunks/chunk121.wav : You know that the tickets that come in or they could be deposit ready could be issues with the platform and maybe measuring.
# audio-chunks/chunk122.wav : That overtime might be a good way to determine if the platforms getting better or more issues arising so maybe that's one.
# audio-chunks/chunk123.wav : Interesting table fan.
# audio-chunks/chunk124.wav : Used rav4.
# audio-chunks/chunk125.wav : Yes please anything that we can do like i said i'm at a real struggle fighting.
# audio-chunks/chunk126.wav : Experience. because they don't have them.
# audio-chunks/chunk127.wav : Remember to send a team meeting for us next week if i'm not mistaken.
# audio-chunks/chunk128.wav : Chrome this week.
# audio-chunks/chunk129.wav : If i if i haven't said it yet.
# audio-chunks/chunk130.wav : Electrical space.
# Error:
# audio-chunks/chunk132.wav : What people are doing our platforms.
# audio-chunks/chunk133.wav : Fart.
# audio-chunks/chunk134.wav : Robin are supposed to be this week.
# audio-chunks/chunk135.wav : And that's kind of where i want to bring up like should we have a big tenant meeting i think there used to be one.
# audio-chunks/chunk136.wav : So that sound works.
# audio-chunks/chunk137.wav : Oh that would be great.
# audio-chunks/chunk138.wav : You said wednesday.
# audio-chunks/chunk139.wav : Do i look to schedule the meeting either thursday or friday and the takeaway or the prep.
# Error:
# audio-chunks/chunk141.wav : Speak about the pain points and the friction points of the stuff that people do with our platform stools.
# audio-chunks/chunk142.wav : Yes absolutely.
# Error:
# audio-chunks/chunk144.wav : That makes sense.
# audio-chunks/chunk145.wav : The other question i had you know just an idea for later on.
# audio-chunks/chunk146.wav : But it'd be cool monthly email digest from tenants.
# audio-chunks/chunk147.wav : You know the written used casing.
# audio-chunks/chunk148.wav : Immediately having his example to byl yamo.
# audio-chunks/chunk149.wav : File currently we have 320 phone boarded.
# audio-chunks/chunk150.wav : And there might be other tenants that might be interested in it stuff like that like things at the times can do or are utilized.
# audio-chunks/chunk151.wav : I think i want to see now.
# audio-chunks/chunk152.wav : So.
# audio-chunks/chunk153.wav : Corte de vela.
# Error:
# audio-chunks/chunk155.wav : In my previous limited something similar and i was able to actually customize every the email to every person because we had a.
# audio-chunks/chunk156.wav : Datasource that was telling us.
# audio-chunks/chunk157.wav : Which dashboard is using was looking at and which ones it wasn't.
# audio-chunks/chunk158.wav : I'm thinking maybe we can do something similar for the tenants and.
# audio-chunks/chunk159.wav : Customize a message them that can maybe be helpful in in.
# audio-chunks/chunk160.wav : Tracking certain behaviors that we might want from the jail.
# audio-chunks/chunk161.wav : Email channel is.
# audio-chunks/chunk162.wav : People expect to get excited about it because that you know they said a rule for it otherwise it comes out from broadcast.
# audio-chunks/chunk163.wav : If you ignore it when you personalize it included.
# audio-chunks/chunk164.wav : Exactly exactly.
# audio-chunks/chunk165.wav : What what we did just like top 10 users of this dashboard versus.
# audio-chunks/chunk166.wav : Versus you know talk to him another one.
# audio-chunks/chunk167.wav : Definitely.
# Error:
# audio-chunks/chunk169.wav : And another thing yeah just following up you know i know we talked about.
# audio-chunks/chunk170.wav : Play van training.
# audio-chunks/chunk171.wav : How are you wanted to work with me in python so.
# audio-chunks/chunk172.wav : I just wanted to bring it up again happy more than happy to do it maybe we have a few.
# audio-chunks/chunk173.wav : Use cases already has.
# audio-chunks/chunk174.wav : What we can do pair programming or something i don't know.
# audio-chunks/chunk175.wav : Yeah that's more about for fun thing on a.
# audio-chunks/chunk176.wav : Robertson friday or something.
# audio-chunks/chunk177.wav : No i'd love to let's get into it i'm trying to think of the best method to learn it as a teacher of python.
# audio-chunks/chunk178.wav : What do you recommend.
# audio-chunks/chunk179.wav : Yeah so in terms of the best method to learn it.
# audio-chunks/chunk180.wav : I mostly having a project is definitely like the best best way to learn it.
# audio-chunks/chunk181.wav : At least for me it is.
# audio-chunks/chunk182.wav : + 9.
# audio-chunks/chunk183.wav : You know having a common jupyter notebook i think would be good for us to work as a team.
# audio-chunks/chunk184.wav : In-n-out in a list python tussaud.
# audio-chunks/chunk185.wav : I'm i'm going to set up i've already started setting up bitbucket.
# audio-chunks/chunk186.wav : I talked to don about the stupid essentially.
# audio-chunks/chunk187.wav : It'd be good for us all.
# audio-chunks/chunk188.wav : Be able to leverage bitbucket to share code amongst each other and.
# audio-chunks/chunk189.wav : And review each other's code cuz i think that'll be a way.
# audio-chunks/chunk190.wav : Wrestler from each other to for example.
# audio-chunks/chunk191.wav : Madonna 9.
# audio-chunks/chunk192.wav : We met on friday one of the ideas proposed as you know when i make a change to the site.
# audio-chunks/chunk193.wav : It go to the bitbucket process into that bitbucket process there's an approval.
# audio-chunks/chunk194.wav : Processing in matter floyd kind of start to see.
# audio-chunks/chunk195.wav : How it's working and and make sure that you know we're all on the same page.
# audio-chunks/chunk196.wav : What i should do.
# audio-chunks/chunk197.wav : You know because we.
# audio-chunks/chunk198.wav : Over the next few.
# audio-chunks/chunk199.wav : We're going to have to work really closely the team to deliver on these metrics that i'm talking about.
# audio-chunks/chunk200.wav : Pause really quick and explain what chris is looking to do with that.
# audio-chunks/chunk201.wav : But the problem is is whenever we face an issue.
# audio-chunks/chunk202.wav : Being our anecdotes for society's anecdote.
# audio-chunks/chunk203.wav : Politics overcomes ethnicity.
# audio-chunks/chunk204.wav : Physically gaining the data points will give us a better foundation and footing when we want to say to it.
# audio-chunks/chunk205.wav : This is not meeting the service-level objectives that we your indicators are off and then.
# audio-chunks/chunk206.wav : This is critically important because i t.
# audio-chunks/chunk207.wav : Rear-ended in a rare exception right now if you're still in ccp.
# audio-chunks/chunk208.wav : Is focus on engaging ccp teks through andy mcclure.
# audio-chunks/chunk209.wav : And sag neur contractor.
# audio-chunks/chunk210.wav : Go and.
# audio-chunks/chunk211.wav : The subcontractors ny.
# audio-chunks/chunk212.wav : Film.
# audio-chunks/chunk213.wav : That scares me half to death because it's going to be direct to the source now you've got a middleman who's annie and he's very good..
# audio-chunks/chunk214.wav : But it will be all that much more important for us to come to the table to annie to give her the ammunition she needs to be able stay.
# audio-chunks/chunk215.wav : Instead of what people have been saying ew is slow right.
# audio-chunks/chunk216.wav : The same look.
# audio-chunks/chunk217.wav : At 5 p.m. traffic is so bad everybody's getting sued and it's causing issues to deliver the business in this missing this query.
# audio-chunks/chunk218.wav : That'll give her as a contractor the evidence she needs to go subcontractor grady.
# Error:
# audio-chunks/chunk220.wav : Thinking that what we do is we meet over the next few weeks and we have a set if you we can work this is a project do it in python.
# audio-chunks/chunk221.wav : Yeah i got a lot of it building out tricks but if we started that.
# audio-chunks/chunk222.wav : Ideate around customer journeys.
# audio-chunks/chunk223.wav : Basics of python.
# audio-chunks/chunk224.wav : Spider.
# audio-chunks/chunk225.wav : How should i comment how should i use bitbucket all that kind of stuff.
# audio-chunks/chunk226.wav : Is an operating model down and then start learning the fundamentals.
# audio-chunks/chunk227.wav : Learn how to integrate.
# audio-chunks/chunk228.wav : Yeah yeah.
# audio-chunks/chunk229.wav : And unfair for those data-driven.
# audio-chunks/chunk230.wav : In almost giving up.
# audio-chunks/chunk231.wav : Annie's fabric.
# audio-chunks/chunk232.wav : Maybe a source.
# audio-chunks/chunk233.wav : For some of that i have to look i'm going to meet with someone from telemetry to make sure.
# audio-chunks/chunk234.wav : I can do some of this no more stuff at aaron's.
# audio-chunks/chunk235.wav : I doing i was being able to measure stop measuring performance resembles.
# audio-chunks/chunk236.wav : Yeah i know that they're working with eric beck.
# audio-chunks/chunk237.wav : Yeah.
# audio-chunks/chunk238.wav : Somebody call the platform.
# Error:
# Error:
# audio-chunks/chunk241.wav : Okay so the next slide on this here.
# audio-chunks/chunk242.wav : So.
# audio-chunks/chunk243.wav : Wanted to show you against two of the.
# audio-chunks/chunk244.wav : Show my previous see my belt things for them.
# audio-chunks/chunk245.wav : I things to two things in particular.
# audio-chunks/chunk246.wav : One of the tableau extension.
# audio-chunks/chunk247.wav : And maybe i can do this.
# audio-chunks/chunk248.wav : Insite portal.
# audio-chunks/chunk249.wav : And this is kind of what i was saying in the chat.
# audio-chunks/chunk250.wav : 4.
# audio-chunks/chunk251.wav : I'm already getting a few things from a few people for wondering.
# audio-chunks/chunk252.wav : Should i ask am i going to continue supporting this.
# audio-chunks/chunk253.wav : Any team.
# audio-chunks/chunk254.wav : So my question is.
# audio-chunks/chunk255.wav : Does this fit within scope of rok arse like a tableau extension.
# audio-chunks/chunk256.wav : Like.
# audio-chunks/chunk257.wav : I mean.
# audio-chunks/chunk258.wav : Sheryl crow.
# Error:
# Error:
# audio-chunks/chunk261.wav : I got you.
# Error:
# audio-chunks/chunk263.wav : So this component here.
# audio-chunks/chunk264.wav : Navigation.
# audio-chunks/chunk265.wav : Tableau extension.
# audio-chunks/chunk266.wav : And you important like a plug-in.
# audio-chunks/chunk267.wav : And what would allows you to do is essentially just navigating months a lot of dashboards.
# audio-chunks/chunk268.wav : I want you have.
# audio-chunks/chunk269.wav : A lot of dashboard.
# Error:
# audio-chunks/chunk271.wav : The folks of used it like it a lot better than.
# audio-chunks/chunk272.wav : Then this type of navigation.
# audio-chunks/chunk273.wav : Navigation here looks.
# audio-chunks/chunk274.wav : Little cleaner looks better it's easier and more convenient.
# audio-chunks/chunk275.wav : So a lot of variable at least a few area products or interested in using this extension.
# audio-chunks/chunk276.wav : Iso.
# audio-chunks/chunk277.wav : Celeste.
# audio-chunks/chunk278.wav : That's pretty much.
# audio-chunks/chunk279.wav : It is some wondering if it's within our scope.
# audio-chunks/chunk280.wav : To support such a thing like this.
# audio-chunks/chunk281.wav : That would be that would be.
# Error:
# Error:
# audio-chunks/chunk284.wav : I am always in favor of anything we could do to remain on the cutting edge closer to the closing business what they need to see what they need to do i have.
# audio-chunks/chunk285.wav : We no longer on the team have any role directly.
# audio-chunks/chunk286.wav : Representing.
# audio-chunks/chunk287.wav : We still have that remix.
# audio-chunks/chunk288.wav : But i'm relying entirely on the technology team with john conlon that guys to warm their duties and follow up when there's ever any problems.
# audio-chunks/chunk289.wav : If we were to expand your role to include the visualization piece i could see that maybe we'd have a niche.
# audio-chunks/chunk290.wav : Frick you in something like this.
# audio-chunks/chunk291.wav : My concern is what kind of support is going to come out what kind of advancements what kind of things are they going to want to do dishes that could eat eat up your time.
# audio-chunks/chunk292.wav : Yeah.
# audio-chunks/chunk293.wav : Yeah that makes sense like as long as it takes up in a small percentage of time you know.
# audio-chunks/chunk294.wav : Continuously supporting but figure right especially the higher priorities are more of the data consumption.
# audio-chunks/chunk295.wav : Pieces of things sound.
# audio-chunks/chunk296.wav : What i would say is eustace is a is a test.
# audio-chunks/chunk297.wav : How easy is this ticket because we're all about cell service and just because a business team relies on another business team.
# audio-chunks/chunk298.wav : Doesn't mean that they're not.
# Error:
# audio-chunks/chunk300.wav : Not to be dependent on it.
# audio-chunks/chunk301.wav : Easton.
# Error:
# audio-chunks/chunk303.wav : Viable for us to market is it go to go to market.
# audio-chunks/chunk304.wav : Cuz if your naked self service then it's it's off living and breathing on its own and then they can.
# audio-chunks/chunk305.wav : Continue..
# Error:
# audio-chunks/chunk307.wav : Do you think they have that skill-set on their team we're thrilled that interest.
# audio-chunks/chunk308.wav : So.
# audio-chunks/chunk309.wav : So what i did so far as far as extension goes is i do treat documentation on how to maintain and create the extension.
# Error:
# audio-chunks/chunk311.wav : You know on their own self.
# audio-chunks/chunk312.wav : I'm actually.
# audio-chunks/chunk313.wav : One of the one of the people sometime in my calendar and i'm going to be able to.
# audio-chunks/chunk314.wav : Ask them like.
# audio-chunks/chunk315.wav : Snowbasin documentation on how you can do this yourself like what are.
# audio-chunks/chunk316.wav : Like what issues are you having.
# Error:
# Error:
# audio-chunks/chunk319.wav : You know one of the things i was working on and in like a later phase is actually more deeply integrating it.
# audio-chunks/chunk320.wav : Into the inside portal.
# audio-chunks/chunk321.wav : Such that it wasn't part of.
# audio-chunks/chunk322.wav : Didn't miss the tableau dashboard was part of it inside portal.
# audio-chunks/chunk323.wav : And then that would make it super self-service because.
# audio-chunks/chunk324.wav : Literally you know that the drop-down options are there.
# audio-chunks/chunk325.wav : It's just a matter of changing the ui a little bit so that it displays in this way.
# Error:
# audio-chunks/chunk327.wav : So.
# audio-chunks/chunk328.wav : Going to ccp in the inside portal integration route.
# audio-chunks/chunk329.wav : That would make it completely self service.
# audio-chunks/chunk330.wav : So that's kind of where it where that was.
# audio-chunks/chunk331.wav : How would that work is that just said what you have them ads that menu far to the.
# audio-chunks/chunk332.wav : Did the portal.
# audio-chunks/chunk333.wav : Breadcrumb.
# audio-chunks/chunk334.wav : Exactly so there's two options for that so one is and actually i had a version uhd.
# Error:
# audio-chunks/chunk336.wav : Demonstrative.
# Error:
# audio-chunks/chunk338.wav : Yeah so there's there's one option of great just integrated into the portal.
# audio-chunks/chunk339.wav : So that it's just like a part of the portal.
# audio-chunks/chunk340.wav : And there was another solution.
# audio-chunks/chunk341.wav : I was looking at an alternative i think this is.
# audio-chunks/chunk342.wav : Correct one.
# audio-chunks/chunk343.wav : But essentially all of the person who's interested in it would have to do is append.
# audio-chunks/chunk344.wav : A url.
# audio-chunks/chunk345.wav : To the portal.
# Error:
# audio-chunks/chunk347.wav : Within the manage content.
# audio-chunks/chunk348.wav : Suction here for every dashboard.
# audio-chunks/chunk349.wav : The person is afraid in the dark but has a lot of options for configuration.
# audio-chunks/chunk350.wav : And through that little form they can configure it and add it that way.
# audio-chunks/chunk351.wav : Winter slowly.
# Error:
# audio-chunks/chunk353.wav : What does that point to a webpage that contains your extension plus an iframe.
# audio-chunks/chunk354.wav : Yeah that's exactly right yeah.
# audio-chunks/chunk355.wav : Dallas run.
# audio-chunks/chunk356.wav : The only place where that might cause problems is when people try to create slides ring.
# audio-chunks/chunk357.wav : Through.
# audio-chunks/chunk358.wav : That's a great point actually that the slide creation piece i think that's where i was starting to run into an issue.
# Error:
# audio-chunks/chunk360.wav : I didn't do i didn't get.
# audio-chunks/chunk361.wav : Or is it.
# audio-chunks/chunk362.wav : So this is the example so i can see it's a little bit bigger.
# audio-chunks/chunk363.wav : That's because.
# Error:
# audio-chunks/chunk365.wav : Mystery.
# audio-chunks/chunk366.wav : Because the way that you can configure it this extension here is not part of the tableau dashboard it's rather.
# audio-chunks/chunk367.wav : Miss the extension is actually rendering the tableau dashboard.
# audio-chunks/chunk368.wav : So is it backwards.
# audio-chunks/chunk369.wav : Iframe within.
# audio-chunks/chunk370.wav : The.
# audio-chunks/chunk371.wav : Lanai extension.
# Error:
# Error:
# audio-chunks/chunk374.wav : So the other options in go as you can see here.
# audio-chunks/chunk375.wav : Like this url.
# audio-chunks/chunk376.wav : You can put it up anywhere.
# audio-chunks/chunk377.wav : Wine essentially.
# audio-chunks/chunk378.wav : What was he doing.
# audio-chunks/chunk379.wav : Well just say this isn't the url for the centrally what it what it was.
# audio-chunks/chunk380.wav : Is.
# audio-chunks/chunk381.wav : You do a forward slash and then the extension url.
# audio-chunks/chunk382.wav : And then what will happen is extension url would load.
# audio-chunks/chunk383.wav : Other than here.
# audio-chunks/chunk384.wav : And then whatever came after this.
# audio-chunks/chunk385.wav : Would a wood mode the dashboard underneath it.
# audio-chunks/chunk386.wav : That's how this is happening.
# audio-chunks/chunk387.wav : So that's another way to make it really self service and really easy for anyone to a disney.
# audio-chunks/chunk388.wav : Simply have to.
# audio-chunks/chunk389.wav : Give extension url followed by the url of their dashboard in this tuition.
# Error:
# audio-chunks/chunk391.wav : Okay.
# audio-chunks/chunk392.wav : Yeah but would.
# audio-chunks/chunk393.wav : With the side creation piece working-out work.
# audio-chunks/chunk394.wav : More testing is needed obviously cuz i haven't.
# audio-chunks/chunk395.wav : Nose running into official with it.
# audio-chunks/chunk396.wav : I just made.
# audio-chunks/chunk397.wav : It looks like it is working like that i guess the slide creation just looks at that url but let's take a look.
# audio-chunks/chunk398.wav : Yeah i have two test one.
# Error:
# audio-chunks/chunk400.wav : I would be cautious just because i know sarah and i know how things could go.
# audio-chunks/chunk401.wav : I'm on survivor weekend.
# audio-chunks/chunk402.wav : Yeah that's 70 show.
# audio-chunks/chunk403.wav : But if you could teach them to do it and it's a good.
# audio-chunks/chunk404.wav : Yeah i can have them.
# audio-chunks/chunk405.wav : Then by all means cuz i'm extension for something that i remember being at the tableau conference.
# audio-chunks/chunk406.wav : Said it was like.
# audio-chunks/chunk407.wav : Yeah.
# audio-chunks/chunk408.wav : You know it was quite the process i'm getting that extension ladder.
# audio-chunks/chunk409.wav : Send a lot of emails you want to follow up yeah that's.
# audio-chunks/chunk410.wav : Self-service.
# audio-chunks/chunk411.wav : If this is not if you don't want to investigate the extensions further.
# Error:
# audio-chunks/chunk413.wav : I'm going to training them up on how to build maintain create whatever.
# audio-chunks/chunk414.wav : Knowledge transfer from you.
# audio-chunks/chunk415.wav : The second option is.
# audio-chunks/chunk416.wav : Casey long is the new product owner for the portal.
# audio-chunks/chunk417.wav : If enough people want it i think i shut you down last time.
# audio-chunks/chunk418.wav : Because.
# audio-chunks/chunk419.wav : Because it was the functionality that only you guys were interested in nobody else.
# audio-chunks/chunk420.wav : So maybe if you guys if you convince casey that it's super easy.
# audio-chunks/chunk421.wav : We could definitely put on the backlog.
# audio-chunks/chunk422.wav : Yeah.
# audio-chunks/chunk423.wav : Yeah i mean it cuz at the end of the day like.
# audio-chunks/chunk424.wav : This this extension you miss navigation.
# audio-chunks/chunk425.wav : Literally.
# audio-chunks/chunk426.wav : This was built using the same library.
# audio-chunks/chunk427.wav : That the ccd inside portal is.
# audio-chunks/chunk428.wav : So just them having the idea of just changing this layout or adding a different layout option.
# audio-chunks/chunk429.wav : With one like this instead of.
# audio-chunks/chunk430.wav : Instead of this up here i think would be ideal in a.
# Error:
# audio-chunks/chunk432.wav : And i think sarah actually i've heard that sarah said she really likes.
# audio-chunks/chunk433.wav : Discipling out.
# audio-chunks/chunk434.wav : And as well as other people so maybe that that would actually be ideal if casey just takes it in.
# Error:
# audio-chunks/chunk436.wav : Set the ad okay so instead.
# audio-chunks/chunk437.wav : A breadcrumb identify where you are to be able to take yourself back through and it was a little bit odd because he had the dashboard link to other dashboards from within themselves that wouldn't.
# Error:
# audio-chunks/chunk439.wav : So.
# audio-chunks/chunk440.wav : Are you saying.
# audio-chunks/chunk441.wav : Replace that breaker bar actual context-specific drop-down that i set up.
# audio-chunks/chunk442.wav : When the content administrator adds the content.
# audio-chunks/chunk443.wav : Yep pretty much and if you look at the inside portal.
# audio-chunks/chunk444.wav : There is.
# audio-chunks/chunk445.wav : You know.
# audio-chunks/chunk446.wav : Lately have all the data they would need to make it.
# audio-chunks/chunk447.wav : As well like for example you know right now that it's cat the navigation is all these different type of chapters.
# audio-chunks/chunk448.wav : And.
# Error:
# audio-chunks/chunk450.wav : You know.
# audio-chunks/chunk451.wav : Let me have enough layers.
# audio-chunks/chunk452.wav : I within their manage content section to be able to.
# audio-chunks/chunk453.wav : Create the chapters so maybe this.
# audio-chunks/chunk454.wav : Play marcel.
# audio-chunks/chunk455.wav : So they would just be pulling the data and just right here in a little bit differently.
# Error:
# Error:
# audio-chunks/chunk458.wav : Puzzle.
# audio-chunks/chunk459.wav : This is going to be overly complicated when we originally sia rising to the layers.
# Error:
# audio-chunks/chunk461.wav : I could put the instead of having.
# audio-chunks/chunk462.wav : What they have now which is what do they call it.
# Error:
# audio-chunks/chunk464.wav : Heather.
# audio-chunks/chunk465.wav : What do they have a manager the first one is.
# audio-chunks/chunk466.wav : Like a category year.
# audio-chunks/chunk467.wav : Portal.
# Error:
# Error:
# audio-chunks/chunk470.wav : Just wondering.
# Error:
# audio-chunks/chunk472.wav : When is kwanzaa.
# audio-chunks/chunk473.wav : I just open one of those if they had originally come to me whenever.
# audio-chunks/chunk474.wav : You can do.
# audio-chunks/chunk475.wav : Put it as app so instead of subcategories and then i could type in.
# audio-chunks/chunk476.wav : Ccp and i could use a character that would be the parsing so it could be a carrot it could be a dash it could be whatever some special character.
# Error:
# audio-chunks/chunk478.wav : Ccp pipe card pipe.
# Error:
# audio-chunks/chunk480.wav : Freedom.
# audio-chunks/chunk481.wav : I freedom unlimited.
# Error:
# audio-chunks/chunk483.wav : Corner awards and instantly the parsing engine would go back through and it would create.
# audio-chunks/chunk484.wav : Stop navigation in the hamburger menu in midland.
# audio-chunks/chunk485.wav : And then.
# Error:
# audio-chunks/chunk487.wav : I meant a little while later they're like.
# Error:
# Error:
# audio-chunks/chunk490.wav : What i'm suggesting when it comes to your extensions if we maybe improvement going back to that make it a pipe and then you can have a different.
# audio-chunks/chunk491.wav : Determine how it would appear when there it would appear in standard.
# audio-chunks/chunk492.wav : Or whether it could be a drop-down menu.
# audio-chunks/chunk493.wav : Something like that.
# Error:
# Error:
# audio-chunks/chunk496.wav : Importantly i know it's a better you i am.
# Error:
# audio-chunks/chunk498.wav : You have the day to do it like this would be the shopper the same category in the topic would be those drop-down minds.
# audio-chunks/chunk499.wav : But what i mean chapters like this operation matches.
# Error:
# audio-chunks/chunk501.wav : Down.
# audio-chunks/chunk502.wav : What if i weeded the pipe method you were talking about orofino that's the meds that they can do that would allow the drop-down you can configure in such a way we're like.
# audio-chunks/chunk503.wav : No you have operational metrics and then you can.
# audio-chunks/chunk504.wav : Open up a sub menu and anakin.
# audio-chunks/chunk505.wav : I can't go for that way.
# Error:
# audio-chunks/chunk507.wav : Amazing isn't it certainly isn't reading.
# Error:
# audio-chunks/chunk509.wav : Different options of the portal is tricky only because the portal resources are really.
# audio-chunks/chunk510.wav : Development.
# audio-chunks/chunk511.wav : Casey would be able to determine the prioritization of.
# audio-chunks/chunk512.wav : Yeah.
# Error:
# audio-chunks/chunk514.wav : The magnifying glass to you.
# audio-chunks/chunk515.wav : Well that was a search.
# audio-chunks/chunk516.wav : Future.
# Error:
# audio-chunks/chunk518.wav : I guess it's coming soon.
# audio-chunks/chunk519.wav : Should i remove that.
# Error:
# audio-chunks/chunk521.wav : Otherside.
# Error:
# audio-chunks/chunk523.wav : Take you through the different.
# audio-chunks/chunk524.wav : Yeah so if you have more than seven chapters i think it was you.
# audio-chunks/chunk525.wav : Yeah seven chapters then you can use that carrot.
# audio-chunks/chunk526.wav : Pekarna ardmore.
# audio-chunks/chunk527.wav : Chapters.
# audio-chunks/chunk528.wav : If not it just keeps cycling through.
# Error:
# Error:
# audio-chunks/chunk531.wav : This was out when using more than 7 convenience.
# audio-chunks/chunk532.wav : Online.
# audio-chunks/chunk533.wav : Carousel.
# Error:
# audio-chunks/chunk535.wav : And then i just had a fleeting.
# audio-chunks/chunk536.wav : What myers briggs have you ever taken one.
# audio-chunks/chunk537.wav : 8/8 yeah when i was a kid teenager and now i took it after i haven't taken it since i was.
# audio-chunks/chunk538.wav : 188.
# audio-chunks/chunk539.wav : Yeah i might i might do it again just to see if i.
# audio-chunks/chunk540.wav : I forgot what i was actually.
# audio-chunks/chunk541.wav : Yeah.
# audio-chunks/chunk542.wav : Circus now you're an enfp.
# Error:
# audio-chunks/chunk544.wav : I think i need to go take the test over again.
# audio-chunks/chunk545.wav : You know each other and stuff like that.
# audio-chunks/chunk546.wav : You know more about her team always now.
# audio-chunks/chunk547.wav : Well.
# Error:
# audio-chunks/chunk549.wav : Yeah that's all the ids and i.
# Error:
# audio-chunks/chunk551.wav : All the questions i have.
# Error:
# audio-chunks/chunk553.wav : I am off on friday but maybe we can meet on thursday to catch you up.
# audio-chunks/chunk554.wav : Miami.
# audio-chunks/chunk555.wav : Or before tina based on.
# audio-chunks/chunk556.wav : That'd be great so far.
# Error:
# audio-chunks/chunk558.wav : Yeah i'll set up the team meetings and then.
# audio-chunks/chunk559.wav : If you could put together like a python curriculum.
# audio-chunks/chunk560.wav : I love the idea of a project we could started as a project that we could work it together as a team.
# Error:
# audio-chunks/chunk562.wav : Nothing is for certain things like nose often bitbucket her how to do certain things may be making a video.
# audio-chunks/chunk563.wav : Just like a short one minute video of like how i do something.
# audio-chunks/chunk564.wav : Maybe that's more effective then and it's easier also just make a quick video on how to do something instead of.
# audio-chunks/chunk565.wav : Writing it out.
# audio-chunks/chunk566.wav : Maybe that's one way so it's also.
# audio-chunks/chunk567.wav : Knowledge.
# Error:
# Error:
# Error:
# Error:
#
# Full text: If you look at an end user journey and i'll just give you an example cuz if we flushed it out with use that this many of our pigs at work. If you look at these are journey of deploying of visualizations into production that he's our journey is not started when i click the button to deploy. Production started when i say. My mind i've developed the dashboard. I want it in production. Now i know i need to go and you know that's technically when when the journey starts cuz i don't know what i'm doing i have to go search for the answer of how to find it we can't really control much about that but that doesn't necessarily mean it's not part of the journey i click on the button. Out of my house. And that is what i'm looking to have as a starting point for all. Journeys to get access to tools. Journey to share work clothes to put your clothes production to run work was eccentric point is when the user can no longer take the next step on their own. They require an automation something else somebody else to step in interview interfere so. Whitsett. I was tableau i want to be able to have a metric. Did i say it takes. Two days we got a tableau dashboard into its production. Analysts on the front end would look at them say that my experience it takes that's accurate. Well one at 1 and 1/2 of those days is actually waiting for your manager to approve it not on a saturday. That is the system say got the approval. Pushed it into production that's the message that we want to be able to deliver to the analysts and we're doing it on a weekly basis so. Looking at those metrics week-over-week i do a lot of them will change a lot. We just want to get that user experience. Triangle. Are we as a team will come up with or need to come up with certain journeys. Against the start clicking the stopwatch is the last step that they can do on their own before they have to make it somebody else's problem and then. And pointed whatever that intent was his result. Gotcha. That makes sense. That's really good contacts. You know this stuff here. They have to. Dad. Geneseo honor all that good stuff. And i think i seen that stopwatch makes sense that i think it starts here but i'll look more into it and then i'll. Provide that information as well. And there could be a back-and-forth again to someone grab td2 would be. Go for psych mpd2 it says envoy the click that so form out. Go. And then it could be a back-and-forth between. I have to do and things i have to do. I make sense. Yeah luckily there is as great onboarding. so i think it'll be a good. Starting point. And i should have you. What i told chris is that. We would start the stopwatch at the last step that a person. What i am. Recognizing that i don't capture when i do that is if the forms that the user has to fill out to click the button to sasa fit go and start stopwatch. Is egregious and horrible and paving. Slingo if you have a way with mpd2 to say no no we've got a very clear way the. The user starts on the floor man gauges with it and then they click this events you could start stopwatch earlier when they open the forum. Ideally would be able to track that at least without fixing the tableau you can't because they. Open it up. Goes off and do something else and then come back and it's not really something that you'd be able to easily track. What makes sense. And then only other. Question i think on that aspect is. Is there any might differ based on which route. The person might take. So. Especially this. Two different ways to connect to empty to and this is where i guess this would be after the onboarding process but you think this. Should be included within that journey or. Can you connect auntie to you know in these five different ways and it might vary depending. What is so i'm sorry what was the question i guess it's part of. The envoy would you consider this as part of on voiding. Like getting the shoes for getting the outfit stool. Getting all these tools. Would you think that that's  ...

# %%
import subprocess
from pydub import AudioSegment
import speech_recognition as sr

def wav_convert_from_mov(file_name):
    sound = AudioSegment.from_file(file_name+".mov", "mov")
    sound.export(file_name+".wav", format="wav")

def text_from_wav(file_name):
    r = sr.Recognizer()
    with sr.AudioFile(file_name+'.wav') as source:
        audio_text = r.listen(source)
        #audio_text = r.record(source)
        # using google speech recognition
        text = r.recognize_sphinx(audio_text)
        #text = r.recognize_google(audio_text, show_all=True)
        print('Converting audio transcripts into text ...')
        #print(text)
        return text

def run(file_name):
    wav_convert_from_mov(file_name)
    return text_from_wav(file_name)

# %%
text = text_from_wav('11-1-21 (Mon) 317PM ')
print (text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/speech_recognition/__init__.py in recognize_sphinx(self, audio_data, language, keyword_entries, grammar, show_all)
#     728         try:
# --> 729             from pocketsphinx import pocketsphinx, Jsgf, FsgModel
#     730
#
# ModuleNotFoundError: No module named 'pocketsphinx'
#
# During handling of the above exception, another exception occurred:
#
# RequestError                              Traceback (most recent call last)
# /var/folders/00/xr38cr8n7xd8vz3n5831t62m0000gn/T/ipykernel_2909/1831860011.py in <module>
# ----> 1 text = text_from_wav('11-1-21 (Mon) 317PM ')
#       2 print (text)
#
# /var/folders/00/xr38cr8n7xd8vz3n5831t62m0000gn/T/ipykernel_2909/2966004099.py in text_from_wav(file_name)
#      13         #audio_text = r.record(source)
#      14         # using google speech recognition
# ---> 15         text = r.recognize_sphinx(audio_text)
#      16         #text = r.recognize_google(audio_text, show_all=True)
#      17         print('Converting audio transcripts into text ...')
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/speech_recognition/__init__.py in recognize_sphinx(self, audio_data, language, keyword_entries, grammar, show_all)
#     730
#     731         except ImportError:
# --> 732             raise RequestError("missing PocketSphinx module: ensure that PocketSphinx is set up correctly.")
#     733         except ValueError:
#     734             raise RequestError("bad PocketSphinx installation; try reinstalling PocketSphinx version 0.0.9 or better.")
#
# RequestError: missing PocketSphinx module: ensure that PocketSphinx is set up correctly.

# %%
import speech_recognition as sr

r = sr.Recognizer()
with sr.AudioFile('jarvis_intro.wav') as source:
    audio_text = r.listen(source)
    try:
        # using google speech recognition
        text = r.recognize_google(audio_text)
        print('Converting audio transcripts into text ...')
        print(text)
    except:
         print('Sorry.. run again...')

# %%
import subprocess
from pydub import AudioSegment

# %%
import time
import speech_recognition as sr


def callback(recognizer, audio):
    try:
        print( recognizer.recognize_google(audio))
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))

r = sr.Recognizer()
m = sr.Microphone()
with m as source:
    r.adjust_for_ambient_noise(source)  
    
stop_listening = r.listen_in_background(m, callback)

while True: time.sleep(0.1)  # we're not listening anymore, even though the background thread might still be running for a second or two while cleaning up and stopping

print ('done')
# Out:
# Google Speech Recognition could not understand audio
# call me when you score by cheating will receive the same one
# KTN news TV Artis to other priorities
# I can ask something
# how
# so do you have any Communications update
# the list of attendees without any actual names
# Google Speech Recognition could not understand audio
# is there anything else that you know anybody will like to share before we come to this meeting about what when I came and I put you on the spot. There's any communication with sending every every other week
# Coco
# Google Speech Recognition could not understand audio
# Google Speech Recognition could not understand audio
# Google Speech Recognition could not understand audio
# Google Speech Recognition could not understand audio
# Google Speech Recognition could not understand audio
# Google Speech Recognition could not understand audio
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/00/xr38cr8n7xd8vz3n5831t62m0000gn/T/ipykernel_1904/1704197660.py in <module>
#      18 stop_listening = r.listen_in_background(m, callback)
#      19
# ---> 20 while True: time.sleep(0.1)  # we're not listening anymore, even though the background thread might still be running for a second or two while cleaning up and stopping
#      21
#      22 print ('done')
#
# KeyboardInterrupt:

# %% [markdown]
# https://cloud.google.com/speech-to-text/docs/quickstart-client-libraries#client-libraries-install-python

# %%
# Imports the Google Cloud client library
from google.cloud import speech


# Instantiates a client
client = speech.SpeechClient()

# The name of the audio file to transcribe
gcs_uri = "gs://cloud-samples-data/speech/brooklyn_bridge.raw"

audio = speech.RecognitionAudio(uri=gcs_uri)

config = speech.RecognitionConfig(
    encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
    sample_rate_hertz=16000,
    language_code="en-US",
)

# Detects speech in the audio file
response = client.recognize(config=config, audio=audio)

for result in response.results:
    print("Transcript: {}".format(result.alternatives[0].transcript))
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# /var/folders/00/xr38cr8n7xd8vz3n5831t62m0000gn/T/ipykernel_2909/2713657597.py in <module>
#       4
#       5 # Instantiates a client
# ----> 6 client = speech.SpeechClient()
#       7
#       8 # The name of the audio file to transcribe
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/google/cloud/speech_v1/services/speech/client.py in __init__(self, credentials, transport, client_options, client_info)
#     322         else:
#     323             Transport = type(self).get_transport_class(transport)
# --> 324             self._transport = Transport(
#     325                 credentials=credentials,
#     326                 credentials_file=client_options.credentials_file,
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/google/cloud/speech_v1/services/speech/transports/grpc.py in __init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access)
#     149
#     150         # The base transport sets the host, credentials and scopes
# --> 151         super().__init__(
#     152             host=host,
#     153             credentials=credentials,
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/google/cloud/speech_v1/services/speech/transports/base.py in __init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, **kwargs)
#     114
#     115         elif credentials is None:
# --> 116             credentials, _ = google.auth.default(
#     117                 **scopes_kwargs, quota_project_id=quota_project_id
#     118             )
#
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/google/auth/_default.py in default(scopes, request, quota_project_id, default_scopes)
#     491             return credentials, effective_project_id
#     492
# --> 493     raise exceptions.DefaultCredentialsError(_HELP_MESSAGE)
#
# DefaultCredentialsError: Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or explicitly create credentials and re-run the application. For more information, please see https://cloud.google.com/docs/authentication/getting-started
